# %%
import os
import pandas
import IPython
import numpy as np
import scipy.io.wavfile as wav


wavdir = 'vctk-p225/wav48/p225'
txtdir = 'vctk-p225/txt/p225'

# %%
# train, test split
allwav = os.listdir(wavdir)

test_size = int(len(allwav)*.1)

test_files = np.random.choice(allwav, size=test_size)
train_files = list(set(allwav).difference(set( test_files)))
len(test_files), len(train_files)
# Out:
# (23, 210)

# %%
from python_speech_features import mfcc
f = os.path.join(wavdir,'p225_176.wav')
IPython.display.Audio(f)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def sparse_tuple_from(sequences, dtype=np.int32):
    indices = []
    values = []

    for n, seq in enumerate(sequences):
        indices.extend(zip([n] * len(seq), range(len(seq))))
        values.extend(seq)

    indices = np.asarray(indices, dtype=np.int64)
    values = np.asarray(values, dtype=dtype)
    shape = np.asarray([len(sequences), np.asarray(indices).max(0)[1] + 1], dtype=np.int64)

    return indices, values, shape

# %%
audio_filename = os.path.join(wavdir,'p225_176.wav')
target_filename = os.path.join(txtdir,'p225_176.txt')
# Constants
SPACE_TOKEN = '<space>'
SPACE_INDEX = 0
FIRST_INDEX = ord('a') - 1  # 0 is reserved to space

def get_batch(audio_filename, target_filename):

    fs, audio = wav.read(audio_filename)

    inputs = mfcc(audio, samplerate=8000)

    train_inputs = np.asarray(inputs[np.newaxis, :])
    train_inputs = (train_inputs - np.mean(train_inputs))/np.std(train_inputs)
    train_seq_len = [train_inputs.shape[1]]

    # Readings targets
    with open(target_filename, 'r') as f:

        line = f.read()

        original = ' '.join(line.strip().lower().split(' ')).replace(",","")\
                      .replace(".","").replace("?","").replace("'","").replace("-", '')
        targets = original.replace(' ', '  ')
        targets = targets.split(' ')

    # Adding blank label
    targets = np.hstack([SPACE_TOKEN if x == '' else list(x) for x in targets])

    # Transform char into index
    targets = np.asarray([SPACE_INDEX if x == SPACE_TOKEN else ord(x) - FIRST_INDEX
                          for x in targets])

    # Creating sparse representation to feed the placeholder
    train_targets = sparse_tuple_from([targets])

    return  train_inputs, train_targets,   train_seq_len, original

# %%
def get_data(train_files):
    data = []
    for i, f in enumerate(train_files):

        audio_filename = os.path.join(wavdir,f)
        target_filename = os.path.join(txtdir,f.replace(".wav", '.txt'))
        train_inputs, train_targets, train_seq_len, original = get_batch(audio_filename, target_filename)
        data.append((train_inputs, train_targets, train_seq_len, original))
    return data

train = get_data(train_files)
test = get_data(test_files)

# %% [markdown]
# # Model

# %%
import tensorflow as tf
num_features = 13
# Accounting the 0th index +  space + blank label = 28 characters
num_classes = ord('z') - ord('a') + 1 + 1 + 1
print(num_classes)

# Hyper-parameters
num_epochs = 100
num_hidden = 100
num_layers = 1
batch_size = 1

num_examples = 1

inputs = tf.placeholder(tf.float32, [None, None, num_features])

# Here we use sparse_placeholder that will generate a
# SparseTensor required by ctc_loss op.
targets = tf.sparse_placeholder(tf.int32)

# 1d array of size [batch_size]
seq_len = tf.placeholder(tf.int32, [None])

# Defining the cell
cell = tf.contrib.rnn.LSTMCell(num_hidden, state_is_tuple=True)

# Stacking rnn cells
stack = tf.contrib.rnn.MultiRNNCell([cell] * num_layers,
                                    state_is_tuple=True)

# The second output is the last state and we will no use that
outputs, _ = tf.nn.dynamic_rnn(stack, inputs, seq_len, dtype=tf.float32)

shape = tf.shape(inputs)
batch_s, max_time_steps = shape[0], shape[1]

# Reshaping to apply the same weights over the timesteps
outputs = tf.reshape(outputs, [-1, num_hidden])


# fully connected layer
logits = tf.contrib.layers.fully_connected(outputs, num_classes, activation_fn = None)

# Reshaping back to the original shape
logits = tf.reshape(logits, [batch_s, -1, num_classes])

# Time major
logits = tf.transpose(logits, (1, 0, 2))

loss = tf.nn.ctc_loss(targets, logits, seq_len)
cost = tf.reduce_mean(loss)


optimizer = tf.train.MomentumOptimizer(learning_rate=0.001, momentum=0.9)#.minimize(cost)

# Gradient Clipping
gradients = optimizer.compute_gradients(cost)
capped_gradients = [(tf.clip_by_value(grad, -5., 5.), var) for grad, var in gradients if grad is not None]
training_op = optimizer.apply_gradients(capped_gradients)


# Option 2: tf.contrib.ctc.ctc_beam_search_decoder
decoded, log_prob = tf.nn.ctc_greedy_decoder(logits, seq_len)

# Inaccuracy: label error rate
ler = tf.reduce_mean(tf.edit_distance(tf.cast(decoded[0], tf.int32),
                                      targets))
# Out:
# /usr/lib/python3/dist-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 28

# %%
import random
import time
from tqdm import tqdm

saver = tf.train.Saver()
with tf.Session() as sess:

    tf.global_variables_initializer().run()
#     saver.restore(sess, "./ctc_model.ckpt")

    for curr_epoch in range(num_epochs):
        train_cost = train_ler = 0
        start = time.time()
        
        idx = list(range(len(train_files)))
        random.shuffle(idx)
    
        for i, f in  enumerate(idx):
            train_inputs, train_targets, train_seq_len, original = train[f]
        
            feed = {inputs: train_inputs,
                        targets: train_targets,
                        seq_len: train_seq_len}

            _ = sess.run([training_op], feed)
            batch_cost, batch_ler = sess.run([cost, ler], feed_dict=feed)

            train_cost += batch_cost
            train_ler += batch_ler


        train_cost /= len(idx)
        train_ler /= len(idx)
        
        f = np.random.choice(list(range(len(test_files))))
        
        val_inputs, val_targets, val_seq_len, val_original = test[f]
        val_feed = {inputs: val_inputs,
                        targets: val_targets,
                        seq_len: val_seq_len}

        val_cost, val_ler = sess.run([cost, ler], feed_dict=val_feed)

        # Decoding
        d = sess.run(decoded[0], feed_dict=val_feed)
        str_decoded = ''.join([chr(x) for x in np.asarray(d[1]) + FIRST_INDEX])
        # Replacing blank label to none
        str_decoded = str_decoded.replace(chr(ord('z') + 1), '')
        # Replacing space label to space
        str_decoded = str_decoded.replace(chr(ord('a') - 1), ' ')

        print('Original val: %s' % val_original)
        print('Decoded val: %s' % str_decoded)
        
        log = "Epoch {}/{}, train_cost = {:.3f}, train_ler = {:.3f}, val_cost = {:.3f}, val_ler = {:.3f}, time = {:.3f}"
        print(log.format(curr_epoch+1, num_epochs, train_cost, train_ler,
                         val_cost, val_ler, time.time() - start))
        saver.save(sess, './ctc_model.ckpt')
# Out:
# Original val: many complicated ideas about the rainbow have been formed
# Decoded val: e
# Epoch 1/100, train_cost = 947.238, train_ler = 1.096, val_cost = 265.664, val_ler = 0.965, time = 194.685
# Original val: thats as it should be
# Decoded val: ht
# Epoch 2/100, train_cost = 200.294, train_ler = 0.938, val_cost = 76.011, val_ler = 0.810, time = 200.406
# Original val: but the commission is on a collision course with the government
# Decoded val: t e
# Epoch 3/100, train_cost = 178.141, train_ler = 0.904, val_cost = 271.058, val_ler = 0.937, time = 196.208
# Original val: we would hope to make progress on that next year
# Decoded val: te
# Epoch 4/100, train_cost = 176.955, train_ler = 0.902, val_cost = 174.496, val_ler = 0.896, time = 198.971
# Original val: it isnt a happy memory
# Decoded val: t
# Epoch 5/100, train_cost = 157.776, train_ler = 0.947, val_cost = 66.002, val_ler = 0.955, time = 198.703
# Original val: six spoons of fresh snow peas five thick slabs of blue cheese and maybe a snack for her brother bob
# Decoded val: th
# Epoch 6/100, train_cost = 122.847, train_ler = 0.983, val_cost = 297.657, val_ler = 0.980, time = 198.215
# Original val: i didnt feel under any pressure
# Decoded val: t
# Epoch 7/100, train_cost = 122.443, train_ler = 0.961, val_cost = 91.687, val_ler = 0.968, time = 197.506
# Original val: overall it was a promising day for the scots
# Decoded val: the
# Epoch 8/100, train_cost = 120.521, train_ler = 0.947, val_cost = 128.082, val_ler = 0.932, time = 198.173
# Original val: we suffered a lot for seven years
# Decoded val: ih
# Epoch 9/100, train_cost = 118.755, train_ler = 0.942, val_cost = 88.444, val_ler = 1.000, time = 203.002
# Original val: in fact he is not even in the squad for the game
# Decoded val: th
# Epoch 10/100, train_cost = 117.213, train_ler = 0.949, val_cost = 131.625, val_ler = 0.958, time = 202.747
# Original val: six spoons of fresh snow peas five thick slabs of blue cheese and maybe a snack for her brother bob
# Decoded val: ie
# Epoch 11/100, train_cost = 113.025, train_ler = 0.953, val_cost = 277.534, val_ler = 0.980, time = 202.287
# Original val: six spoons of fresh snow peas five thick slabs of blue cheese and maybe a snack for her brother bob
# Decoded val: ie
# Epoch 12/100, train_cost = 115.598, train_ler = 0.955, val_cost = 287.300, val_ler = 0.980, time = 202.711
# Original val: many complicated ideas about the rainbow have been formed
# Decoded val: i
# Epoch 13/100, train_cost = 113.386, train_ler = 0.955, val_cost = 170.799, val_ler = 0.982, time = 202.892
# Original val: i think hes the favourite
# Decoded val: i
# Epoch 14/100, train_cost = 117.064, train_ler = 0.965, val_cost = 74.121, val_ler = 0.960, time = 203.041
# Original val: there is  according to legend a boiling pot of gold at one end
# Decoded val: t
# Epoch 15/100, train_cost = 113.598, train_ler = 0.970, val_cost = 166.147, val_ler = 0.984, time = 203.038
# Original val: it isnt a happy memory
# Decoded val: i
# Epoch 16/100, train_cost = 111.335, train_ler = 0.970, val_cost = 60.777, val_ler = 0.955, time = 202.621
# Original val: she said the charity would continue to monitor the case
# Decoded val: i
# Epoch 17/100, train_cost = 111.269, train_ler = 0.971, val_cost = 138.793, val_ler = 0.982, time = 201.929
# Original val: she said the charity would continue to monitor the case
# Decoded val: i
# Epoch 18/100, train_cost = 107.837, train_ler = 0.965, val_cost = 147.285, val_ler = 0.982, time = 201.759
# Original val: overall it was a promising day for the scots
# Decoded val: th
# Epoch 19/100, train_cost = 107.287, train_ler = 0.970, val_cost = 109.326, val_ler = 0.955, time = 202.704
# Original val: it isnt a happy memory
# Decoded val: i
# Epoch 20/100, train_cost = 106.749, train_ler = 0.965, val_cost = 52.463, val_ler = 0.955, time = 202.435
# Original val: we would hope to make progress on that next year
# Decoded val: i
# Epoch 21/100, train_cost = 107.581, train_ler = 0.964, val_cost = 136.466, val_ler = 1.000, time = 194.685
# Original val: we have a clean bill of health
# Decoded val: t
# Epoch 22/100, train_cost = 116.964, train_ler = 0.966, val_cost = 88.370, val_ler = 0.967, time = 188.560
# Original val: in fact he is not even in the squad for the game
# Decoded val: i
# Epoch 23/100, train_cost = 114.487, train_ler = 0.966, val_cost = 132.832, val_ler = 0.979, time = 199.371
# Original val: i think hes the favourite
# Decoded val: t
# Epoch 24/100, train_cost = 108.436, train_ler = 0.969, val_cost = 72.789, val_ler = 0.960, time = 203.337
# Original val: in fact he is not even in the squad for the game
# Decoded val: i
# Epoch 25/100, train_cost = 111.234, train_ler = 0.968, val_cost = 128.040, val_ler = 0.979, time = 203.178
# Original val: it isnt a happy memory
# Decoded val: ih
# Epoch 26/100, train_cost = 113.224, train_ler = 0.969, val_cost = 61.476, val_ler = 0.909, time = 202.757
# Original val: overall it was a promising day for the scots
# Decoded val: i
# Epoch 27/100, train_cost = 117.649, train_ler = 0.962, val_cost = 114.007, val_ler = 0.977, time = 205.158
# Original val: overall it was a promising day for the scots
# Decoded val: i
# Epoch 28/100, train_cost = 110.819, train_ler = 0.973, val_cost = 109.332, val_ler = 0.977, time = 205.162
# Original val: it isnt a happy memory
# Decoded val: i
# Epoch 29/100, train_cost = 109.794, train_ler = 0.976, val_cost = 69.010, val_ler = 0.955, time = 205.743
# Original val: we have a clean bill of health
# Decoded val: t
# Epoch 30/100, train_cost = 112.002, train_ler = 0.970, val_cost = 80.022, val_ler = 0.967, time = 203.133
# Original val: he is delighted and he has every right to be
# Decoded val: i
# Epoch 31/100, train_cost = 112.722, train_ler = 0.973, val_cost = 120.244, val_ler = 0.977, time = 196.166
# Original val: diving is no part of football
# Decoded val: t
# Epoch 32/100, train_cost = 112.146, train_ler = 0.974, val_cost = 87.318, val_ler = 0.966, time = 198.390
# Original val: thats as it should be
# Decoded val: t
# Epoch 33/100, train_cost = 108.723, train_ler = 0.974, val_cost = 51.381, val_ler = 0.952, time = 196.540
# Original val: i didnt feel under any pressure
# Decoded val: t
# Epoch 34/100, train_cost = 107.231, train_ler = 0.976, val_cost = 79.176, val_ler = 0.968, time = 196.384
# Original val: at that point the structure of the board was changed
# Decoded val: t
# Epoch 35/100, train_cost = 105.360, train_ler = 0.981, val_cost = 130.442, val_ler = 0.981, time = 190.814
# Original val: many complicated ideas about the rainbow have been formed
# Decoded val:  b
# Epoch 36/100, train_cost = 106.159, train_ler = 0.982, val_cost = 155.768, val_ler = 0.965, time = 189.227
# Original val: in fact he is not even in the squad for the game
# Decoded val:
# Epoch 37/100, train_cost = 104.876, train_ler = 0.984, val_cost = 133.657, val_ler = 1.000, time = 200.926
# Original val: at that point the structure of the board was changed
# Decoded val:
# Epoch 38/100, train_cost = 104.931, train_ler = 0.983, val_cost = 134.377, val_ler = 1.000, time = 207.091
# Original val: six spoons of fresh snow peas five thick slabs of blue cheese and maybe a snack for her brother bob
# Decoded val: b
# Epoch 39/100, train_cost = 102.831, train_ler = 0.983, val_cost = 255.168, val_ler = 0.990, time = 206.709
# Original val: it isnt a happy memory
# Decoded val: t
# Epoch 40/100, train_cost = 101.901, train_ler = 0.982, val_cost = 52.446, val_ler = 0.955, time = 203.647
# Original val: but the commission is on a collision course with the government
# Decoded val:
# Epoch 41/100, train_cost = 105.828, train_ler = 0.980, val_cost = 182.310, val_ler = 1.000, time = 190.053
# Original val: i didnt feel under any pressure
# Decoded val: t
# Epoch 42/100, train_cost = 108.861, train_ler = 0.982, val_cost = 78.171, val_ler = 0.968, time = 189.843
# Original val: six spoons of fresh snow peas five thick slabs of blue cheese and maybe a snack for her brother bob
# Decoded val:
# Epoch 43/100, train_cost = 105.801, train_ler = 0.979, val_cost = 279.051, val_ler = 1.000, time = 191.370
# Original val: but the commission is on a collision course with the government
# Decoded val:
# Epoch 44/100, train_cost = 127.192, train_ler = 0.980, val_cost = 183.681, val_ler = 1.000, time = 188.597
# Original val: inside the atmosphere was quiet
# Decoded val: theee
# Epoch 45/100, train_cost = 138.177, train_ler = 0.969, val_cost = 108.038, val_ler = 0.839, time = 188.884
# Original val: he is delighted and he has every right to be
# Decoded val: the
# Epoch 46/100, train_cost = 145.502, train_ler = 0.958, val_cost = 142.490, val_ler = 0.909, time = 188.323
# Original val: we have a clean bill of health
# Decoded val: i
# Epoch 47/100, train_cost = 130.418, train_ler = 0.951, val_cost = 88.472, val_ler = 0.933, time = 188.813
# Original val: we would hope to make progress on that next year
# Decoded val: i
# Epoch 48/100, train_cost = 173.081, train_ler = 0.976, val_cost = 158.659, val_ler = 1.000, time = 189.295
# Original val: thats as it should be
# Decoded val:
# Epoch 49/100, train_cost = 140.242, train_ler = 0.987, val_cost = 79.820, val_ler = 1.000, time = 186.541
# Original val: i think hes the favourite
# Decoded val: t
# Epoch 50/100, train_cost = 132.548, train_ler = 0.989, val_cost = 75.780, val_ler = 0.960, time = 191.956
# Original val: six spoons of fresh snow peas five thick slabs of blue cheese and maybe a snack for her brother bob
# Decoded val: i
# Epoch 51/100, train_cost = 131.290, train_ler = 0.984, val_cost = 360.371, val_ler = 0.990, time = 185.849
# Original val: i think hes the favourite
# Decoded val: t
# Epoch 52/100, train_cost = 127.752, train_ler = 0.976, val_cost = 73.476, val_ler = 0.960, time = 186.677
# Original val: thats as it should be
# Decoded val: t
# Epoch 53/100, train_cost = 128.452, train_ler = 0.973, val_cost = 59.617, val_ler = 0.952, time = 186.179
# Original val: i didnt feel under any pressure
# Decoded val: t
# Epoch 54/100, train_cost = 128.576, train_ler = 0.956, val_cost = 137.783, val_ler = 0.968, time = 187.381
# Original val: he added that he was very sad about o neill
# Decoded val: t
# Epoch 55/100, train_cost = 128.503, train_ler = 0.950, val_cost = 122.186, val_ler = 0.977, time = 188.434
# Original val: we suffered a lot for seven years
# Decoded val: th
# Epoch 56/100, train_cost = 125.807, train_ler = 0.940, val_cost = 100.136, val_ler = 0.939, time = 188.790
# Original val: many complicated ideas about the rainbow have been formed
# Decoded val: ih iie
# Epoch 57/100, train_cost = 123.261, train_ler = 0.915, val_cost = 271.963, val_ler = 0.877, time = 189.371
# Original val: she said the charity would continue to monitor the case
# Decoded val: ih
# Epoch 58/100, train_cost = 112.281, train_ler = 0.950, val_cost = 139.203, val_ler = 0.964, time = 193.960
# Original val: we have a clean bill of health
# Decoded val: t
# Epoch 59/100, train_cost = 108.180, train_ler = 0.959, val_cost = 72.206, val_ler = 0.967, time = 188.806
# Original val: but the commission is on a collision course with the government
# Decoded val: tt
# Epoch 60/100, train_cost = 107.745, train_ler = 0.963, val_cost = 140.464, val_ler = 0.968, time = 189.126
# Original val: it isnt a happy memory
# Decoded val: i
# Epoch 61/100, train_cost = 105.110, train_ler = 0.963, val_cost = 49.712, val_ler = 0.955, time = 189.192
# Original val: inside the atmosphere was quiet
# Decoded val: th
# Epoch 62/100, train_cost = 104.532, train_ler = 0.965, val_cost = 91.500, val_ler = 0.935, time = 189.024
# Original val: there is  according to legend a boiling pot of gold at one end
# Decoded val: i
# Epoch 63/100, train_cost = 106.256, train_ler = 0.960, val_cost = 169.781, val_ler = 0.984, time = 189.453
# Original val: we have a clean bill of health
# Decoded val: t
# Epoch 64/100, train_cost = 107.291, train_ler = 0.960, val_cost = 79.216, val_ler = 0.967, time = 188.860
# Original val: some have accepted it as a miracle without physical explanation
# Decoded val: th
# Epoch 65/100, train_cost = 107.435, train_ler = 0.959, val_cost = 231.305, val_ler = 0.889, time = 196.480
# Original val: inside the atmosphere was quiet
# Decoded val: t
# Epoch 66/100, train_cost = 104.069, train_ler = 0.958, val_cost = 88.537, val_ler = 0.968, time = 205.415
# Original val: thats as it should be
# Decoded val: t
# Epoch 67/100, train_cost = 104.324, train_ler = 0.957, val_cost = 50.574, val_ler = 0.952, time = 200.108
# Original val: i think hes the favourite
# Decoded val: t
# Epoch 68/100, train_cost = 105.414, train_ler = 0.957, val_cost = 67.396, val_ler = 0.960, time = 196.088
# Original val: i think hes the favourite
# Decoded val:  e
# Epoch 69/100, train_cost = 118.139, train_ler = 0.945, val_cost = 86.867, val_ler = 0.840, time = 195.204
# Original val: but the commission is on a collision course with the government
# Decoded val: th
# Epoch 70/100, train_cost = 127.934, train_ler = 0.950, val_cost = 285.802, val_ler = 0.968, time = 194.648
# Original val: six spoons of fresh snow peas five thick slabs of blue cheese and maybe a snack for her brother bob
# Decoded val: ih
# Epoch 71/100, train_cost = 155.185, train_ler = 0.932, val_cost = 355.110, val_ler = 0.980, time = 196.401
# Original val: some have accepted it as a miracle without physical explanation
# Decoded val: ie
# Epoch 72/100, train_cost = 139.678, train_ler = 0.929, val_cost = 228.072, val_ler = 0.952, time = 195.006
# Original val: he is delighted and he has every right to be
# Decoded val: ih
# Epoch 73/100, train_cost = 136.823, train_ler = 0.919, val_cost = 147.244, val_ler = 0.932, time = 194.042
# Original val: thats as it should be
# Decoded val: the a
# Epoch 74/100, train_cost = 144.499, train_ler = 0.910, val_cost = 62.081, val_ler = 0.762, time = 193.817
# Original val: overall it was a promising day for the scots
# Decoded val: it
# Epoch 75/100, train_cost = 141.824, train_ler = 0.910, val_cost = 141.372, val_ler = 0.932, time = 204.918
# Original val: thats as it should be
# Decoded val: te
# Epoch 76/100, train_cost = 137.810, train_ler = 0.912, val_cost = 61.286, val_ler = 0.905, time = 198.181
# Original val: he is delighted and he has every right to be
# Decoded val: ihe s
# Epoch 77/100, train_cost = 137.409, train_ler = 0.906, val_cost = 129.808, val_ler = 0.886, time = 197.212
# Original val: but the commission is on a collision course with the government
# Decoded val: ihe
# Epoch 78/100, train_cost = 139.417, train_ler = 0.898, val_cost = 258.739, val_ler = 0.937, time = 195.436
# Original val: but the commission is on a collision course with the government
# Decoded val: th
# Epoch 79/100, train_cost = 137.458, train_ler = 0.890, val_cost = 214.358, val_ler = 0.952, time = 189.935
# Original val: inside the atmosphere was quiet
# Decoded val: th
# Epoch 80/100, train_cost = 135.465, train_ler = 0.890, val_cost = 107.428, val_ler = 0.903, time = 188.228
# Original val: inside the atmosphere was quiet
# Decoded val: thel
# Epoch 81/100, train_cost = 146.031, train_ler = 0.883, val_cost = 102.234, val_ler = 0.903, time = 189.826
# Original val: diving is no part of football
# Decoded val: toicn
# Epoch 82/100, train_cost = 132.243, train_ler = 0.891, val_cost = 89.866, val_ler = 0.931, time = 189.231
# Original val: diving is no part of football
# Decoded val: th h
# Epoch 83/100, train_cost = 140.740, train_ler = 0.887, val_cost = 102.950, val_ler = 0.931, time = 190.645
# Original val: many complicated ideas about the rainbow have been formed
# Decoded val: ih a a a
# Epoch 84/100, train_cost = 136.707, train_ler = 0.880, val_cost = 203.283, val_ler = 0.860, time = 192.252
# Original val: thats as it should be
# Decoded val: t t
# Epoch 85/100, train_cost = 141.040, train_ler = 0.894, val_cost = 61.848, val_ler = 0.810, time = 190.625
# Original val: some have accepted it as a miracle without physical explanation
# Decoded val: ih
# Epoch 86/100, train_cost = 133.816, train_ler = 0.884, val_cost = 206.283, val_ler = 0.952, time = 193.516
# Original val: but the commission is on a collision course with the government
# Decoded val: tho
# Epoch 87/100, train_cost = 129.164, train_ler = 0.894, val_cost = 236.028, val_ler = 0.937, time = 187.768
# Original val: but the commission is on a collision course with the government
# Decoded val: thewee
# Epoch 88/100, train_cost = 130.485, train_ler = 0.894, val_cost = 283.437, val_ler = 0.905, time = 188.234
# Original val: but the commission is on a collision course with the government
# Decoded val: the
# Epoch 89/100, train_cost = 135.766, train_ler = 0.879, val_cost = 229.744, val_ler = 0.937, time = 188.649
# Original val: we would hope to make progress on that next year
# Decoded val: io
# Epoch 90/100, train_cost = 132.021, train_ler = 0.881, val_cost = 154.721, val_ler = 0.958, time = 188.605
# Original val: she said the charity would continue to monitor the case
# Decoded val: it
# Epoch 91/100, train_cost = 131.750, train_ler = 0.890, val_cost = 157.403, val_ler = 0.945, time = 192.316
# Original val: he is delighted and he has every right to be
# Decoded val: io
# Epoch 92/100, train_cost = 131.677, train_ler = 0.895, val_cost = 136.297, val_ler = 0.932, time = 185.620
# Original val: he added that he was very sad about o neill
# Decoded val: t o
# Epoch 93/100, train_cost = 129.659, train_ler = 0.891, val_cost = 128.457, val_ler = 0.930, time = 190.531
# Original val: it isnt a happy memory
# Decoded val: ie o
# Epoch 94/100, train_cost = 127.647, train_ler = 0.885, val_cost = 74.005, val_ler = 0.864, time = 188.043
# Original val: at that point the structure of the board was changed
# Decoded val: it a
# Epoch 95/100, train_cost = 125.769, train_ler = 0.882, val_cost = 148.245, val_ler = 0.904, time = 188.491
# Original val: but the commission is on a collision course with the government
# Decoded val: the se
# Epoch 96/100, train_cost = 129.612, train_ler = 0.874, val_cost = 196.250, val_ler = 0.889, time = 189.354
# Original val: overall it was a promising day for the scots
# Decoded val: thw
# Epoch 97/100, train_cost = 131.479, train_ler = 0.874, val_cost = 145.630, val_ler = 0.909, time = 188.086
# Original val: thats as it should be
# Decoded val: toe s ttt
# Epoch 98/100, train_cost = 133.008, train_ler = 0.876, val_cost = 60.206, val_ler = 0.762, time = 188.393
# Original val: she said the charity would continue to monitor the case
# Decoded val: t
# Epoch 99/100, train_cost = 128.382, train_ler = 0.871, val_cost = 157.801, val_ler = 0.945, time = 188.547
# Original val: some have accepted it as a miracle without physical explanation
# Decoded val: ihe ai
# Epoch 100/100, train_cost = 123.702, train_ler = 0.879, val_cost = 198.575, val_ler = 0.905, time = 188.807
